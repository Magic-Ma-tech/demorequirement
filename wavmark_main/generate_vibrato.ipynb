# %%
from vibrato import *

# %%
process_folder('wavmark_test_50','wavmark_vibrato')
# Out:
# Processing wavmark_test_50/wavmark_7176-88083-0025.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_7176-88083-0025.wav
# Processing wavmark_test_50/wavmark_1995-1836-0009.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_1995-1836-0009.wav
# Processing wavmark_test_50/wavmark_260-123288-0015.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_260-123288-0015.wav
# Processing wavmark_test_50/wavmark_8230-279154-0030.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_8230-279154-0030.wav
# Processing wavmark_test_50/wavmark_1995-1826-0005.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_1995-1826-0005.wav
# Processing wavmark_test_50/wavmark_672-122797-0053.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_672-122797-0053.wav
# Processing wavmark_test_50/wavmark_2094-142345-0007.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_2094-142345-0007.wav
# Processing wavmark_test_50/wavmark_3575-170457-0043.wav...
# Saved to wavmark_vibrato/vibrato_wavmark_3575-170457-0043.wav
# ...
